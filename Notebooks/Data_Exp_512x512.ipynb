# %% [markdown]
# # Skin Cancer Image Classification

# %%
# Import Relevant Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as mpimg


import warnings
warnings.filterwarnings('ignore')

# %%
# !ls ../data/ISIC_IMAGES_512x512/Add_ISIC/
# Out:
# image_add
# train_add.csv

# %% [markdown]
# **DATASET-1:**
#
# Originated from https://challenge2020.isic-archive.com/,
#
# I will use resized images from: https://www.kaggle.com/cdeotte/jpeg-melanoma-512x512?select=train.csv

# %% [markdown]
# **DATASET-2:**
#
# Originated from: https://challenge2019.isic-archive.com/
#
# I will use resized images from: https://www.kaggle.com/cdeotte/jpeg-isic2019-512x512

# %% [markdown]
# **DATASET-3:**
#
# Originated from ISIC Archive: https://www.isic-archive.com/#!/topWithHeader/onlyHeaderTop/gallery?filter=%5B%5D
#
#
# I will use resized images from: https://www.kaggle.com/c/siim-isic-melanoma-classification/discussion/169139
#
# JPEG folder of the 580 new never seen before malignant images

# %% [markdown]
# - All images in the datasets have 512x512 sample size.

# %%
# define datasets
df2020 = pd.read_csv('../data/ISIC_IMAGES_512x512/ISIC2020/train2020.csv')
df2019 = pd.read_csv('../data/ISIC_IMAGES_512x512/ISIC2019/train2019.csv')
dfAdd = pd.read_csv('../data/ISIC_IMAGES_512x512/Add_ISIC/train_add.csv')

# %%
# define the file path
data2020_dir = '../data/ISIC_IMAGES_512x512/ISIC2020/image2020/'
data2019_dir = '../data/ISIC_IMAGES_512x512/ISIC2019/image2019/'
dataAdd_dir = '../data/ISIC_IMAGES_512x512/Add_ISIC/image_add/'

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### ISIC - 2020 DATASET

# %%
df2020
# Out:
#          image_name  patient_id     sex  age_approx  \
# 0      ISIC_2637011  IP_7279968    male        45.0
# 1      ISIC_0015719  IP_3075186  female        45.0
# 2      ISIC_0052212  IP_2842074  female        50.0
# 3      ISIC_0068279  IP_6890425  female        45.0
# 4      ISIC_0074268  IP_8723313  female        55.0
# ...             ...         ...     ...         ...
# 33121  ISIC_9999134  IP_6526534    male        50.0
# 33122  ISIC_9999320  IP_3650745    male        65.0
# 33123  ISIC_9999515  IP_2026598    male        20.0
# 33124  ISIC_9999666  IP_7702038    male        50.0
# 33125  ISIC_9999806  IP_0046310    male        45.0
#
#       anatom_site_general_challenge diagnosis benign_malignant  target  \
# 0                         head/neck   unknown           benign       0
# 1                   upper extremity   unknown           benign       0
# 2                   lower extremity     nevus           benign       0
# 3                         head/neck   unknown           benign       0
# 4                   upper extremity   unknown           benign       0
# ...                             ...       ...              ...     ...
# 33121                         torso   unknown           benign       0
# 33122                         torso   unknown           benign       0
# 33123               lower extremity   unknown           benign       0
# 33124               lower extremity   unknown           benign       0
# 33125                         torso     nevus           benign       0
#
#        tfrecord  width  height
# 0             0   6000    4000
# 1             0   6000    4000
# 2             6   1872    1053
# 3             0   1872    1053
# 4            11   6000    4000
# ...         ...    ...     ...
# 33121         2   2592    1936
# 33122        11   6000    4000
# 33123         3   1872    1053
# 33124        11   1872    1053
# 33125         4   1872    1053
#
# [33126 rows x 11 columns]

# %%
df2020['target'].value_counts()
# Out:
# 0    32542
# 1      584
# Name: target, dtype: int64

# %%
df2020['target'].value_counts(normalize=True)
# Out:
# 0    0.98237
# 1    0.01763
# Name: target, dtype: float64

# %% [markdown]
# - We have a very big class difference between bening and malignant images.

# %%
# add image's path data to train and test set
df2020['path'] = data2020_dir + df2020['image_name'] + ".jpg"

# %%
df2020
# Out:
#          image_name  patient_id     sex  age_approx  \
# 0      ISIC_2637011  IP_7279968    male        45.0
# 1      ISIC_0015719  IP_3075186  female        45.0
# 2      ISIC_0052212  IP_2842074  female        50.0
# 3      ISIC_0068279  IP_6890425  female        45.0
# 4      ISIC_0074268  IP_8723313  female        55.0
# ...             ...         ...     ...         ...
# 33121  ISIC_9999134  IP_6526534    male        50.0
# 33122  ISIC_9999320  IP_3650745    male        65.0
# 33123  ISIC_9999515  IP_2026598    male        20.0
# 33124  ISIC_9999666  IP_7702038    male        50.0
# 33125  ISIC_9999806  IP_0046310    male        45.0
#
#       anatom_site_general_challenge diagnosis benign_malignant  target  \
# 0                         head/neck   unknown           benign       0
# 1                   upper extremity   unknown           benign       0
# 2                   lower extremity     nevus           benign       0
# 3                         head/neck   unknown           benign       0
# 4                   upper extremity   unknown           benign       0
# ...                             ...       ...              ...     ...
# 33121                         torso   unknown           benign       0
# 33122                         torso   unknown           benign       0
# 33123               lower extremity   unknown           benign       0
# 33124               lower extremity   unknown           benign       0
# 33125                         torso     nevus           benign       0
#
#        tfrecord  width  height  \
# 0             0   6000    4000
# 1             0   6000    4000
# 2             6   1872    1053
# 3             0   1872    1053
# 4            11   6000    4000
# ...         ...    ...     ...
# 33121         2   2592    1936
# 33122        11   6000    4000
# 33123         3   1872    1053
# 33124        11   1872    1053
# 33125         4   1872    1053
#
#                                                     path
# 0      ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# 1      ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# 2      ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# 3      ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# 4      ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# ...                                                  ...
# 33121  ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# 33122  ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# 33123  ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# 33124  ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# 33125  ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
#
# [33126 rows x 12 columns]

# %%
# look into 3 image samples:
for im in df2020['path'][:3]:
    img = mpimg.imread(im)
    imgplot = plt.imshow(img)
    plt.show()

# %% [markdown]
# ### ISIC - 2019 DATASET

# %%
df2019
# Out:
#          image_name  patient_id     sex  age_approx  \
# 0      ISIC_0000000          -1  female        55.0
# 1      ISIC_0000001          -1  female        30.0
# 2      ISIC_0000002          -1  female        60.0
# 3      ISIC_0000003          -1    male        30.0
# 4      ISIC_0000004          -1    male        80.0
# ...             ...         ...     ...         ...
# 25326  ISIC_0073247          -1  female        85.0
# 25327  ISIC_0073248          -1    male        65.0
# 25328  ISIC_0073249          -1    male        70.0
# 25329  ISIC_0073251          -1  female        55.0
# 25330  ISIC_0073254          -1    male        50.0
#
#       anatom_site_general_challenge diagnosis benign_malignant  target  \
# 0                    anterior torso        NV           benign       0
# 1                    anterior torso        NV           benign       0
# 2                   upper extremity       MEL        malignant       1
# 3                   upper extremity        NV           benign       0
# 4                   posterior torso       MEL        malignant       1
# ...                             ...       ...              ...     ...
# 25326                     head/neck       BCC           benign       0
# 25327                anterior torso       BKL           benign       0
# 25328               lower extremity       MEL        malignant       1
# 25329                   palms/soles        NV           benign       0
# 25330               upper extremity       BKL           benign       0
#
#        tfrecord  width  height  \
# 0             4   1022     767
# 1            18   1022     767
# 2             0   1022     767
# 3            24   1022     767
# 4            14   1022     767
# ...         ...    ...     ...
# 25326        19   1024    1024
# 25327         7   1024    1024
# 25328         9   1024    1024
# 25329        15   1024    1024
# 25330        23   1024    1024
#
#                                                     path
# 0      ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# 1      ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# 2      ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# 3      ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# 4      ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# ...                                                  ...
# 25326  ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# 25327  ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# 25328  ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# 25329  ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# 25330  ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
#
# [25331 rows x 12 columns]

# %%
df2019['target'].value_counts()
# Out:
# 0    20809
# 1     4522
# Name: target, dtype: int64

# %%
# add image's path data to train and test set
df2019['path'] = data2019_dir + df2019['image_name'] + ".jpg"

# %%
# look into 3 image samples:
for im in df2019['path'][:3]:
    img = mpimg.imread(im)
    imgplot = plt.imshow(img)
    plt.show()

# %% [markdown]
# ### ISIC ARCHIVE ADDITIONAL MALIGNANT DATASET

# %%
dfAdd
# Out:
#        image_name  patient_id     sex  age_approx  \
# 0    ISIC_0000070          -1    male        25.0
# 1    ISIC_0000076          -1    male        55.0
# 2    ISIC_0000144          -1     NaN         NaN
# 3    ISIC_0000158          -1  female        30.0
# 4    ISIC_0000284          -1    male        80.0
# ..            ...         ...     ...         ...
# 575  ISIC_0024302          -1  female        25.0
# 576  ISIC_0024303          -1    male        60.0
# 577  ISIC_0024304          -1    male        70.0
# 578  ISIC_0024305          -1    male        85.0
# 579  ISIC_0036065          -1    male        80.0
#
#     anatom_site_general_challenge                diagnosis benign_malignant  \
# 0                  anterior torso                 melanoma        malignant
# 1                 posterior torso                 melanoma        malignant
# 2                             NaN                 melanoma        malignant
# 3                 upper extremity                 melanoma        malignant
# 4                       head/neck                 melanoma        malignant
# ..                            ...                      ...              ...
# 575                           NaN                 melanoma        malignant
# 576                           NaN  squamous cell carcinoma        malignant
# 577                           NaN  squamous cell carcinoma        malignant
# 578                           NaN  squamous cell carcinoma        malignant
# 579                           NaN                 melanoma        malignant
#
#      target  width  height                     source  ext  tfrecord
# 0         1   1022     767                      UDA-1  jpg        15
# 1         1   1504    1129                      UDA-1  jpg        15
# 2         1   2048    1536                      UDA-1  jpg        15
# 3         1    722     542                      UDA-1  jpg        15
# 4         1   1024     768                      UDA-1  jpg        15
# ..      ...    ...     ...                        ...  ...       ...
# 575       1   3008    2000  2018 JID Editorial Images  jpg        29
# 576       1   3008    2000  2018 JID Editorial Images  jpg        29
# 577       1   3008    2000  2018 JID Editorial Images  jpg        29
# 578       1   4288    2848  2018 JID Editorial Images  jpg        29
# 579       1   2880    1800  2018 JID Editorial Images  png        29
#
# [580 rows x 13 columns]

# %%
dfAdd['target'].value_counts()
# Out:
# 1    580
# Name: target, dtype: int64

# %%
# add image's path data to train and test set
dfAdd['path'] = dataAdd_dir + dfAdd['image_name'] + ".jpg"

# %%
# look into 3 image samples:
for im in dfAdd['path'][:3]:
    img = mpimg.imread(im)
    imgplot = plt.imshow(img)
    plt.show()

# %% [markdown]
# ## Final Dataset:

# %% [markdown]
# In the final dataset, we will use all df2020 and add only malignant images from df2019 and dfAdd datasets.

# %%
df2019_mal = df2019[df2019['benign_malignant'] == 'malignant']
df2019_mal
# Out:
#                      image_name  patient_id     sex  age_approx  \
# 2                  ISIC_0000002          -1  female        60.0
# 4                  ISIC_0000004          -1    male        80.0
# 12                 ISIC_0000013          -1  female        30.0
# 21     ISIC_0000022_downsampled          -1  female        55.0
# 25     ISIC_0000026_downsampled          -1  female        30.0
# ...                         ...         ...     ...         ...
# 25316              ISIC_0073231          -1  female        55.0
# 25319              ISIC_0073237          -1  female        45.0
# 25320              ISIC_0073238          -1  female        45.0
# 25322              ISIC_0073241          -1    male        60.0
# 25328              ISIC_0073249          -1    male        70.0
#
#       anatom_site_general_challenge diagnosis benign_malignant  target  \
# 2                   upper extremity       MEL        malignant       1
# 4                   posterior torso       MEL        malignant       1
# 12                  posterior torso       MEL        malignant       1
# 21                  lower extremity       MEL        malignant       1
# 25                  lower extremity       MEL        malignant       1
# ...                             ...       ...              ...     ...
# 25316                anterior torso       MEL        malignant       1
# 25319               lower extremity       MEL        malignant       1
# 25320               upper extremity       MEL        malignant       1
# 25322                   palms/soles       MEL        malignant       1
# 25328               lower extremity       MEL        malignant       1
#
#        tfrecord  width  height  \
# 2             0   1022     767
# 4            14   1022     767
# 12           20   1022     767
# 21           14   1024     768
# 25           14   1024     768
# ...         ...    ...     ...
# 25316        17   1024    1024
# 25319        11   1024    1024
# 25320        11   1024    1024
# 25322        13   1024    1024
# 25328         9   1024    1024
#
#                                                     path
# 2      ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# 4      ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# 12     ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# 21     ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# 25     ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# ...                                                  ...
# 25316  ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# 25319  ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# 25320  ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# 25322  ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
# 25328  ../data/ISIC_IMAGES_512x512/ISIC2019/image2019...
#
# [4522 rows x 12 columns]

# %%
df_final = pd.concat([df2020, df2019_mal, dfAdd], axis=0, ignore_index= True)
df_final
# Out:
#          image_name  patient_id     sex  age_approx  \
# 0      ISIC_2637011  IP_7279968    male        45.0
# 1      ISIC_0015719  IP_3075186  female        45.0
# 2      ISIC_0052212  IP_2842074  female        50.0
# 3      ISIC_0068279  IP_6890425  female        45.0
# 4      ISIC_0074268  IP_8723313  female        55.0
# ...             ...         ...     ...         ...
# 38223  ISIC_0024302          -1  female        25.0
# 38224  ISIC_0024303          -1    male        60.0
# 38225  ISIC_0024304          -1    male        70.0
# 38226  ISIC_0024305          -1    male        85.0
# 38227  ISIC_0036065          -1    male        80.0
#
#       anatom_site_general_challenge                diagnosis benign_malignant  \
# 0                         head/neck                  unknown           benign
# 1                   upper extremity                  unknown           benign
# 2                   lower extremity                    nevus           benign
# 3                         head/neck                  unknown           benign
# 4                   upper extremity                  unknown           benign
# ...                             ...                      ...              ...
# 38223                           NaN                 melanoma        malignant
# 38224                           NaN  squamous cell carcinoma        malignant
# 38225                           NaN  squamous cell carcinoma        malignant
# 38226                           NaN  squamous cell carcinoma        malignant
# 38227                           NaN                 melanoma        malignant
#
#        target  tfrecord  width  height  \
# 0           0         0   6000    4000
# 1           0         0   6000    4000
# 2           0         6   1872    1053
# 3           0         0   1872    1053
# 4           0        11   6000    4000
# ...       ...       ...    ...     ...
# 38223       1        29   3008    2000
# 38224       1        29   3008    2000
# 38225       1        29   3008    2000
# 38226       1        29   4288    2848
# 38227       1        29   2880    1800
#
#                                                     path  \
# 0      ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# 1      ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# 2      ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# 3      ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# 4      ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# ...                                                  ...
# 38223  ../data/ISIC_IMAGES_512x512/Add_ISIC/image_add...
# 38224  ../data/ISIC_IMAGES_512x512/Add_ISIC/image_add...
# 38225  ../data/ISIC_IMAGES_512x512/Add_ISIC/image_add...
# 38226  ../data/ISIC_IMAGES_512x512/Add_ISIC/image_add...
# 38227  ../data/ISIC_IMAGES_512x512/Add_ISIC/image_add...
#
#                           source  ext
# 0                            NaN  NaN
# 1                            NaN  NaN
# 2                            NaN  NaN
# 3                            NaN  NaN
# 4                            NaN  NaN
# ...                          ...  ...
# 38223  2018 JID Editorial Images  jpg
# 38224  2018 JID Editorial Images  jpg
# 38225  2018 JID Editorial Images  jpg
# 38226  2018 JID Editorial Images  jpg
# 38227  2018 JID Editorial Images  png
#
# [38228 rows x 14 columns]

# %%
df_final['target'].value_counts(normalize=True)
# Out:
# 0    0.851261
# 1    0.148739
# Name: target, dtype: float64

# %% [markdown]
# We still have class imbalance problem, but this is better than having 1% for minority class.

# %%
# Save the final dataset
df_final.to_csv('../data/ISIC_FINAL_DATASET_512x512.csv', index=False)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# create a copy of df_final for EDA purposes:
df_copy = df_final[['image_name', 'path', 'sex', 'age_approx', 'anatom_site_general_challenge', 'benign_malignant']]
df_copy
# Out:
#          image_name                                               path  \
# 0      ISIC_2637011  ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# 1      ISIC_0015719  ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# 2      ISIC_0052212  ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# 3      ISIC_0068279  ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# 4      ISIC_0074268  ../data/ISIC_IMAGES_512x512/ISIC2020/image2020...
# ...             ...                                                ...
# 38223  ISIC_0024302  ../data/ISIC_IMAGES_512x512/Add_ISIC/image_add...
# 38224  ISIC_0024303  ../data/ISIC_IMAGES_512x512/Add_ISIC/image_add...
# 38225  ISIC_0024304  ../data/ISIC_IMAGES_512x512/Add_ISIC/image_add...
# 38226  ISIC_0024305  ../data/ISIC_IMAGES_512x512/Add_ISIC/image_add...
# 38227  ISIC_0036065  ../data/ISIC_IMAGES_512x512/Add_ISIC/image_add...
#
#           sex  age_approx anatom_site_general_challenge benign_malignant
# 0        male        45.0                     head/neck           benign
# 1      female        45.0               upper extremity           benign
# 2      female        50.0               lower extremity           benign
# 3      female        45.0                     head/neck           benign
# 4      female        55.0               upper extremity           benign
# ...       ...         ...                           ...              ...
# 38223  female        25.0                           NaN        malignant
# 38224    male        60.0                           NaN        malignant
# 38225    male        70.0                           NaN        malignant
# 38226    male        85.0                           NaN        malignant
# 38227    male        80.0                           NaN        malignant
#
# [38228 rows x 6 columns]

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38228 entries, 0 to 38227
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   image_name                     38228 non-null  object
#  1   path                           38228 non-null  object
#  2   sex                            38130 non-null  object
#  3   age_approx                     38052 non-null  float64
#  4   anatom_site_general_challenge  37465 non-null  object
#  5   benign_malignant               38228 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 1.8+ MB

# %%
df_copy.isna().sum()
# Out:
# image_name                         0
# path                               0
# sex                               98
# age_approx                       176
# anatom_site_general_challenge    763
# benign_malignant                   0
# dtype: int64

# %%
# Creating a histogram to visualize the class imbalance
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.histplot(data=df_copy, x="benign_malignant")
plt.ylabel("Number of Images")
plt.xlabel("Category")
plt.title('Distribution of Skin Lesion Images');

# %%
# Creating a histogram to visualize age distribution
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.histplot(data=df_copy, x="age_approx")
plt.ylabel("Number of People")
plt.xlabel("Age")
plt.title('Age Distribution');

# %%
# Creating a histogram to visualize sex
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.histplot(data=df_copy.dropna(), x="sex")
plt.ylabel("Number of People")
plt.xlabel("Sex")
plt.title('Sex Distribution');

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.histplot(data=df_copy.dropna(), x="benign_malignant", hue="sex",  multiple="stack")
plt.ylabel("Number of People")
plt.xlabel("Category")
plt.title('Sex Distribution for Each Category');
